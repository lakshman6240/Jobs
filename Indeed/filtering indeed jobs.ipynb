# %%
# %run "../common functions"

# %%
from pyspark.sql.functions import lit

# %%
spark.sql('truncate table staging_catalogue.jobs.indeedjobs')
all_jobs = spark.table("raw_catalogue.jobs.indeedjobs")
jobs = all_jobs.select("url","description","skills").collect()

# %%
scored_jobs = score_job(jobs, "url", "description", "skills")

# %%
scored_df = spark.createDataFrame(scored_jobs)
df = scored_df.join(all_jobs, on=['url'])
filtered_df = df.filter(df.score > 60)
filtered_df = filtered_df.withColumn('location', lit('Hyderabad'))
filtered_df.write.mode('overwrite').option("mergeSchema", "true").saveAsTable("staging_catalogue.jobs.indeedjobs")

# %%
display(filtered_df)
